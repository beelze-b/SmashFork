# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width: 80% !important; }</style>"))
# Out:
# <style>.container {width: 80% !important; }</style>

# %%
import sys
import time
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib import colors

# %%
myColors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
            '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
            '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000',
            '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', 
            '#307D7E', '#000000', "#DDEFFF", "#000035", "#7B4F4B", 
            "#A1C299", "#300018", "#C2FF99", "#0AA6D8", "#013349", 
            "#00846F", "#8CD0FF", "#3B9700", "#04F757", "#C8A1A1", 
            "#1E6E00", "#DFFB71", "#868E7E", "#513A01", "#CCAA35"]

colors2 = plt.cm.Reds(np.linspace(0, 1, 128))
colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,20))
colorsComb = np.vstack([colors3, colors2])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)

# %%
sys.path.append("../../../functions")
from SMaSH_functions import SMaSH_functions

sf = SMaSH_functions()
# Out:
#  * Initialising ...
# WARNING:tensorflow:From ../../../functions/SMaSH_functions.py:70: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
sys.path.append("/home/ubuntu/Taneda/Functions")
from scRNA_functions import scRNA_functions

fc = scRNA_functions()
# Out:
#  * Initialising ...
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Loading annData object

# %%
obj = sc.read_h5ad('../../../../../External_datasets/mouse_brain_all_cells_20200625_with_annotations.h5ad')
obj.X = obj.X.toarray()
obj = obj[obj.obs["Cell broad annotation"]=="Inh"]

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 31053 genes across 8471 cells

# %%
new_sub_annotation = []
for c in obj.obs["Cell sub annotation"].tolist():
    if c in ['Inh_1', 'Inh_2', 'Inh_3', 'Inh_4', 'Inh_5', 'Inh_6']:
        new_sub_annotation.append('Inh')
    elif c in ['Inh_Meis2_1', 'Inh_Meis2_2', 'Inh_Meis2_3', 'Inh_Meis2_4']:
        new_sub_annotation.append('Inh_Meis2')
    else:
        new_sub_annotation.append(c)
obj.obs["Cell sub annotation"] = new_sub_annotation
obj.obs["Cell sub annotation"] = obj.obs["Cell sub annotation"].astype("category")
# Out:
# Trying to set attribute `.obs` of view, copying.

# %% [markdown]
# #### Data preparation

# %%
sf.data_preparation(obj)

# %% [markdown]
# #### Removing general genes

# %%
s1 = time.time()

# %%
obj = sf.remove_general_genes(obj, species='mouse')

# %% [markdown]
# #### Removing house-keeping genes
#
# http://www.housekeeping.unicamp.br/?homePageGlobal

# %%
obj = sf.remove_housekeepingenes(obj, path="../../../data/house_keeping_genes_Mouse_cortex.txt")

# %% [markdown]
# #### Removing genes expressed in less than 30% within groups

# %%
obj = sf.remove_features_pct(obj, group_by="Cell sub annotation", pct=0.3)

# %% [markdown]
# #### Removing genes expressed in more than 50% in a given group where genes are expressed for more 75% within a given group

# %%
obj = sf.remove_features_pct_2groups(obj, group_by="Cell sub annotation", pct1=0.75, pct2=0.5)

# %% [markdown]
# #### Revert PCA

# %%
obj = sf.scale_filter_features(obj, n_components=None, filter_expression=True)
# Out:
# Fraction passing PCA: 0.9882533197139939

# %%
obj.var.set_index(obj.var["SYMBOL"], inplace=True, drop=False)
obj.var.index.name = None

# %% [markdown]
# #### DNN

# %%
s2 = time.time()

# %%
sf.DNN(obj, group_by="Cell sub annotation", model=None, balance=True, verbose=True, save=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                123872
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# activation_1 (Activation)    (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 102
# =================================================================
# Total params: 124,694
# Trainable params: 124,598
# Non-trainable params: 96
# _________________________________________________________________
# None
# Epoch 1/100
# 68/68 [==============================] - 2s 16ms/step - loss: 1.5064 - accuracy: 0.3140 - auc: 0.6834 - precision: 0.7971 - recall: 0.0048 - val_loss: 1.3327 - val_accuracy: 0.7841 - val_auc: 0.9567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 1.33270, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 2/100
# 68/68 [==============================] - 0s 6ms/step - loss: 1.0800 - accuracy: 0.7358 - auc: 0.9408 - precision: 0.9998 - recall: 0.0452 - val_loss: 1.0551 - val_accuracy: 0.9575 - val_auc: 0.9955 - val_precision: 1.0000 - val_recall: 0.0460
#
# Epoch 00002: val_loss improved from 1.33270 to 1.05505, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 3/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.8955 - accuracy: 0.8386 - auc: 0.9744 - precision: 0.9992 - recall: 0.1410 - val_loss: 0.8538 - val_accuracy: 0.9740 - val_auc: 0.9984 - val_precision: 1.0000 - val_recall: 0.3422
#
# Epoch 00003: val_loss improved from 1.05505 to 0.85379, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 4/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.7530 - accuracy: 0.8869 - auc: 0.9874 - precision: 0.9991 - recall: 0.3053 - val_loss: 0.6576 - val_accuracy: 0.9841 - val_auc: 0.9995 - val_precision: 1.0000 - val_recall: 0.5917
#
# Epoch 00004: val_loss improved from 0.85379 to 0.65762, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 5/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.6181 - accuracy: 0.9309 - auc: 0.9937 - precision: 0.9964 - recall: 0.5006 - val_loss: 0.5274 - val_accuracy: 0.9853 - val_auc: 0.9997 - val_precision: 0.9979 - val_recall: 0.8584
#
# Epoch 00005: val_loss improved from 0.65762 to 0.52738, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 6/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.5244 - accuracy: 0.9435 - auc: 0.9967 - precision: 0.9967 - recall: 0.6447 - val_loss: 0.4812 - val_accuracy: 0.9794 - val_auc: 0.9994 - val_precision: 0.9979 - val_recall: 0.8560
#
# Epoch 00006: val_loss improved from 0.52738 to 0.48121, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 7/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.4474 - accuracy: 0.9596 - auc: 0.9978 - precision: 0.9964 - recall: 0.7537 - val_loss: 0.3528 - val_accuracy: 0.9876 - val_auc: 0.9998 - val_precision: 0.9969 - val_recall: 0.9516
#
# Epoch 00007: val_loss improved from 0.48121 to 0.35276, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 8/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.3685 - accuracy: 0.9703 - auc: 0.9987 - precision: 0.9975 - recall: 0.8402 - val_loss: 0.3281 - val_accuracy: 0.9858 - val_auc: 0.9997 - val_precision: 0.9956 - val_recall: 0.9445
#
# Epoch 00008: val_loss improved from 0.35276 to 0.32810, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 9/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.3212 - accuracy: 0.9750 - auc: 0.9992 - precision: 0.9963 - recall: 0.8897 - val_loss: 0.2713 - val_accuracy: 0.9864 - val_auc: 0.9998 - val_precision: 0.9945 - val_recall: 0.9593
#
# Epoch 00009: val_loss improved from 0.32810 to 0.27128, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 10/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.2683 - accuracy: 0.9819 - auc: 0.9995 - precision: 0.9953 - recall: 0.9205 - val_loss: 0.2247 - val_accuracy: 0.9870 - val_auc: 0.9999 - val_precision: 0.9958 - val_recall: 0.9717
#
# Epoch 00010: val_loss improved from 0.27128 to 0.22474, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 11/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.2260 - accuracy: 0.9827 - auc: 0.9996 - precision: 0.9946 - recall: 0.9359 - val_loss: 0.2104 - val_accuracy: 0.9870 - val_auc: 0.9998 - val_precision: 0.9946 - val_recall: 0.9705
#
# Epoch 00011: val_loss improved from 0.22474 to 0.21043, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 12/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1953 - accuracy: 0.9882 - auc: 0.9998 - precision: 0.9963 - recall: 0.9489 - val_loss: 0.1802 - val_accuracy: 0.9882 - val_auc: 0.9998 - val_precision: 0.9910 - val_recall: 0.9723
#
# Epoch 00012: val_loss improved from 0.21043 to 0.18024, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 13/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1708 - accuracy: 0.9872 - auc: 0.9998 - precision: 0.9959 - recall: 0.9604 - val_loss: 0.1502 - val_accuracy: 0.9882 - val_auc: 0.9999 - val_precision: 0.9940 - val_recall: 0.9811
#
# Epoch 00013: val_loss improved from 0.18024 to 0.15023, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 14/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1520 - accuracy: 0.9890 - auc: 0.9998 - precision: 0.9965 - recall: 0.9683 - val_loss: 0.1235 - val_accuracy: 0.9876 - val_auc: 0.9999 - val_precision: 0.9934 - val_recall: 0.9841
#
# Epoch 00014: val_loss improved from 0.15023 to 0.12348, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 15/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1400 - accuracy: 0.9917 - auc: 0.9999 - precision: 0.9979 - recall: 0.9745 - val_loss: 0.1332 - val_accuracy: 0.9858 - val_auc: 0.9998 - val_precision: 0.9904 - val_recall: 0.9788
#
# Epoch 00015: val_loss did not improve from 0.12348
# Epoch 16/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1205 - accuracy: 0.9949 - auc: 0.9999 - precision: 0.9993 - recall: 0.9803 - val_loss: 0.1008 - val_accuracy: 0.9882 - val_auc: 0.9999 - val_precision: 0.9923 - val_recall: 0.9841
#
# Epoch 00016: val_loss improved from 0.12348 to 0.10082, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 17/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1108 - accuracy: 0.9922 - auc: 0.9999 - precision: 0.9975 - recall: 0.9815 - val_loss: 0.1161 - val_accuracy: 0.9841 - val_auc: 0.9998 - val_precision: 0.9887 - val_recall: 0.9788
#
# Epoch 00017: val_loss did not improve from 0.10082
# Epoch 18/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0959 - accuracy: 0.9958 - auc: 1.0000 - precision: 0.9977 - recall: 0.9876 - val_loss: 0.1039 - val_accuracy: 0.9841 - val_auc: 0.9998 - val_precision: 0.9881 - val_recall: 0.9794
#
# Epoch 00018: val_loss did not improve from 0.10082
# Epoch 19/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0930 - accuracy: 0.9960 - auc: 1.0000 - precision: 0.9986 - recall: 0.9896 - val_loss: 0.0819 - val_accuracy: 0.9853 - val_auc: 0.9999 - val_precision: 0.9887 - val_recall: 0.9829
# Epoch 00019: val_loss improved from 0.10082 to 0.08195, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 20/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0817 - accuracy: 0.9942 - auc: 1.0000 - precision: 0.9979 - recall: 0.9886 - val_loss: 0.0853 - val_accuracy: 0.9882 - val_auc: 0.9999 - val_precision: 0.9893 - val_recall: 0.9841
#
# Epoch 00020: val_loss did not improve from 0.08195
# Epoch 21/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0787 - accuracy: 0.9958 - auc: 1.0000 - precision: 0.9993 - recall: 0.9908 - val_loss: 0.0758 - val_accuracy: 0.9882 - val_auc: 0.9999 - val_precision: 0.9887 - val_recall: 0.9817
#
# Epoch 00021: val_loss improved from 0.08195 to 0.07581, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 22/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0717 - accuracy: 0.9960 - auc: 1.0000 - precision: 0.9989 - recall: 0.9906 - val_loss: 0.0837 - val_accuracy: 0.9847 - val_auc: 0.9998 - val_precision: 0.9869 - val_recall: 0.9799
#
# Epoch 00022: val_loss did not improve from 0.07581
# Epoch 23/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0643 - accuracy: 0.9968 - auc: 1.0000 - precision: 0.9984 - recall: 0.9926 - val_loss: 0.0746 - val_accuracy: 0.9847 - val_auc: 0.9998 - val_precision: 0.9864 - val_recall: 0.9805
#
# Epoch 00023: val_loss improved from 0.07581 to 0.07463, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 24/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0638 - accuracy: 0.9968 - auc: 1.0000 - precision: 0.9984 - recall: 0.9934 - val_loss: 0.0592 - val_accuracy: 0.9876 - val_auc: 0.9999 - val_precision: 0.9905 - val_recall: 0.9853
#
# Epoch 00024: val_loss improved from 0.07463 to 0.05920, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 25/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0576 - accuracy: 0.9981 - auc: 1.0000 - precision: 0.9986 - recall: 0.9961 - val_loss: 0.0577 - val_accuracy: 0.9888 - val_auc: 0.9999 - val_precision: 0.9911 - val_recall: 0.9829
#
# Epoch 00025: val_loss improved from 0.05920 to 0.05766, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 26/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0520 - accuracy: 0.9972 - auc: 1.0000 - precision: 0.9982 - recall: 0.9941 - val_loss: 0.0642 - val_accuracy: 0.9858 - val_auc: 0.9999 - val_precision: 0.9870 - val_recall: 0.9823
#
# Epoch 00026: val_loss did not improve from 0.05766
# Epoch 27/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0488 - accuracy: 0.9984 - auc: 1.0000 - precision: 0.9994 - recall: 0.9949 - val_loss: 0.0628 - val_accuracy: 0.9847 - val_auc: 0.9998 - val_precision: 0.9870 - val_recall: 0.9823
#
# Epoch 00027: val_loss did not improve from 0.05766
# Epoch 28/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0471 - accuracy: 0.9985 - auc: 1.0000 - precision: 0.9994 - recall: 0.9971 - val_loss: 0.0499 - val_accuracy: 0.9888 - val_auc: 0.9999 - val_precision: 0.9905 - val_recall: 0.9853
#
# Epoch 00028: val_loss improved from 0.05766 to 0.04988, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 29/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0466 - accuracy: 0.9973 - auc: 1.0000 - precision: 0.9986 - recall: 0.9947 - val_loss: 0.0539 - val_accuracy: 0.9853 - val_auc: 0.9999 - val_precision: 0.9870 - val_recall: 0.9835
#
# Epoch 00029: val_loss did not improve from 0.04988
# Epoch 30/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0392 - accuracy: 0.9977 - auc: 1.0000 - precision: 0.9984 - recall: 0.9958 - val_loss: 0.0585 - val_accuracy: 0.9853 - val_auc: 0.9998 - val_precision: 0.9870 - val_recall: 0.9817
#
# Epoch 00030: val_loss did not improve from 0.04988
# Epoch 31/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0357 - accuracy: 0.9987 - auc: 1.0000 - precision: 0.9994 - recall: 0.9975 - val_loss: 0.0433 - val_accuracy: 0.9888 - val_auc: 0.9999 - val_precision: 0.9899 - val_recall: 0.9864
#
# Epoch 00031: val_loss improved from 0.04988 to 0.04332, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 32/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0376 - accuracy: 0.9985 - auc: 1.0000 - precision: 0.9991 - recall: 0.9976 - val_loss: 0.0500 - val_accuracy: 0.9858 - val_auc: 0.9999 - val_precision: 0.9876 - val_recall: 0.9841
#
# Epoch 00032: val_loss did not improve from 0.04332
# Epoch 33/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0344 - accuracy: 0.9991 - auc: 1.0000 - precision: 0.9992 - recall: 0.9976 - val_loss: 0.0511 - val_accuracy: 0.9841 - val_auc: 0.9998 - val_precision: 0.9864 - val_recall: 0.9829
#
# Epoch 00033: val_loss did not improve from 0.04332
# Epoch 34/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0321 - accuracy: 0.9980 - auc: 1.0000 - precision: 0.9990 - recall: 0.9963 - val_loss: 0.0507 - val_accuracy: 0.9847 - val_auc: 0.9998 - val_precision: 0.9864 - val_recall: 0.9817
#
# Epoch 00034: val_loss did not improve from 0.04332
# Epoch 35/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0331 - accuracy: 0.9989 - auc: 1.0000 - precision: 0.9995 - recall: 0.9960 - val_loss: 0.0473 - val_accuracy: 0.9858 - val_auc: 0.9998 - val_precision: 0.9864 - val_recall: 0.9835
#
# Epoch 00035: val_loss did not improve from 0.04332
# Epoch 36/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0305 - accuracy: 0.9984 - auc: 1.0000 - precision: 0.9988 - recall: 0.9971 - val_loss: 0.0419 - val_accuracy: 0.9870 - val_auc: 0.9999 - val_precision: 0.9899 - val_recall: 0.9853
#
# Epoch 00036: val_loss improved from 0.04332 to 0.04193, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 37/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0264 - accuracy: 0.9988 - auc: 1.0000 - precision: 0.9992 - recall: 0.9974 - val_loss: 0.0402 - val_accuracy: 0.9882 - val_auc: 0.9999 - val_precision: 0.9899 - val_recall: 0.9864
#
# Epoch 00037: val_loss improved from 0.04193 to 0.04025, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 38/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0256 - accuracy: 0.9992 - auc: 1.0000 - precision: 0.9994 - recall: 0.9980 - val_loss: 0.0363 - val_accuracy: 0.9894 - val_auc: 0.9999 - val_precision: 0.9900 - val_recall: 0.9888
#
# Epoch 00038: val_loss improved from 0.04025 to 0.03633, saving model to weights/best_model_Cell sub annotation.h5
# Epoch 39/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0245 - accuracy: 0.9994 - auc: 1.0000 - precision: 0.9996 - recall: 0.9989 - val_loss: 0.0431 - val_accuracy: 0.9853 - val_auc: 0.9999 - val_precision: 0.9876 - val_recall: 0.9847
#
# Epoch 00039: val_loss did not improve from 0.03633
# Epoch 40/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0246 - accuracy: 0.9976 - auc: 1.0000 - precision: 0.9982 - recall: 0.9972 - val_loss: 0.0420 - val_accuracy: 0.9858 - val_auc: 0.9999 - val_precision: 0.9858 - val_recall: 0.9858
#
# Epoch 00040: val_loss did not improve from 0.03633
# Epoch 41/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0232 - accuracy: 0.9990 - auc: 1.0000 - precision: 0.9992 - recall: 0.9981 - val_loss: 0.0445 - val_accuracy: 0.9853 - val_auc: 0.9999 - val_precision: 0.9864 - val_recall: 0.9853
#
# Epoch 00041: val_loss did not improve from 0.03633
# Epoch 42/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0231 - accuracy: 0.9998 - auc: 1.0000 - precision: 0.9999 - recall: 0.9991 - val_loss: 0.0394 - val_accuracy: 0.9870 - val_auc: 0.9999 - val_precision: 0.9876 - val_recall: 0.9864
#
# Epoch 00042: val_loss did not improve from 0.03633
# Epoch 43/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0207 - accuracy: 0.9984 - auc: 1.0000 - precision: 0.9994 - recall: 0.9983 - val_loss: 0.0409 - val_accuracy: 0.9858 - val_auc: 0.9998 - val_precision: 0.9876 - val_recall: 0.9829
#
# Epoch 00043: val_loss did not improve from 0.03633
# Epoch 00043: early stopping
#               precision    recall  f1-score   support
#
#          Inh       1.00      0.98      0.99       841
#    Inh_Lamp5       0.98      0.98      0.98        66
#    Inh_Meis2       0.98      1.00      0.99       390
#    Inh_Pvalb       0.98      0.98      0.98       161
#      Inh_Sst       0.95      0.96      0.95       128
#      Inh_Vip       0.96      0.99      0.98       109
#
#     accuracy                           0.99      1695
#    macro avg       0.98      0.98      0.98      1695
# weighted avg       0.99      0.99      0.99      1695
#
# 53/53 [==============================] - 0s 1ms/step - loss: 0.0363 - accuracy: 0.9894 - auc: 0.9999 - precision: 0.9900 - recall: 0.9888

# %% [markdown]
# #### Shap value

# %%
selectedGenes, selectedGenes_dict = sf.run_shap(obj, group_by="Cell sub annotation", model=None, verbose=True, pct=0.1, restrict_top=("local", 20))

# %%
e2 = time.time()

# %% [markdown]
# #### Classifiers

# %%
sf.run_classifiers(obj, group_by="Cell sub annotation", genes=selectedGenes, classifier="KNN", balance=True, title="DNN-KNN", save=True)
# Out:
# Warning: class_weight cannot be applied on KNN.
# Accuracy: 0.9830841856805664: Misclassification: 0.016915814319433564
#               precision    recall  f1-score   support
#
#          Inh       0.99      0.99      0.99      1262
#    Inh_Lamp5       0.98      0.96      0.97        99
#    Inh_Meis2       0.98      1.00      0.99       584
#    Inh_Pvalb       0.96      0.97      0.97       241
#      Inh_Sst       0.96      0.93      0.94       192
#      Inh_Vip       0.98      0.98      0.98       164
#
#     accuracy                           0.98      2542
#    macro avg       0.98      0.97      0.97      2542
# weighted avg       0.98      0.98      0.98      2542

# %% [markdown]
# #### Sorting genes per cluster

# %%
axs, selectedGenes_top_dict = sf.sort_and_plot(obj, selectedGenes, group_by="Cell sub annotation", group_by2=None, top=3, figsize=(8,14))

# %%
e1 = time.time()

# %%
axs.savefig("Figures/DNN_top5_perGroup.pdf")

# %% [markdown]
# # Elapsed time

# %%
print("%d genes across %s cells"%(obj.n_vars, obj.n_obs))
# Out:
# 3870 genes across 8471 cells

# %%
print('Elapsed time (s): ', e1-s1)
# Out:
# Elapsed time (s):  134.62617349624634

# %%
print('Elapsed time (s): ', e2-s2)
# Out:
# Elapsed time (s):  63.75145244598389
